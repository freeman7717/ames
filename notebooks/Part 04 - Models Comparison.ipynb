# %%
import pandas as pd

# %%
import numpy as np
import pickle
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline

from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA

from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVR
from catboost import CatBoostClassifier

# %%
import plotly.graph_objects as go

# %%
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from tqdm import tqdm

# %% [markdown]
# # Загружаем ранее посчитанные модели

# %%
with open('baseline.pickle', 'rb') as f:
    results = pickle.load(f)
results_df = pd.DataFrame(results)
results_df
# Out:
#           Model                                        Best Params  \
# 0           KNN  {'regressor__n_neighbors': 7, 'regressor__p': ...
# 1    ElasticNet  {'regressor__alpha': 0.07, 'regressor__l1_rati...
# 2  RandomForest  {'regressor__max_depth': 23, 'regressor__n_est...
#
#    Validation r2   Test R²   Test MAE  Test RMSE  \
# 0       0.858822  0.861995  19.347841  28.108901
# 1       0.911070  0.914270  16.065511  22.154541
# 2       0.907528  0.905332  16.317320  23.280833
#
#                                       Best Estimator
# 0  (ColumnTransformer(transformers=[('num',\n    ...
# 1  (ColumnTransformer(transformers=[('num',\n    ...
# 2  (ColumnTransformer(transformers=[('num',\n    ...

# %%
with open('classification.pickle', 'rb') as f:
    classification_df = pickle.load(f)

# %%
with open('regression.pickle', 'rb') as f:
    models = pickle.load(f)

# %%
with open('x_test.pickle', 'rb') as f:
    X_test = pickle.load(f)

# %%
with open('y_test.pickle', 'rb') as f:
    y_test = pickle.load(f)

# %%
base_model = results["Best Estimator"][1]
base_model
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['MS SubClass',
#                                                    'Lot Frontage', 'Lot Area',
#                                                    'Overall Qual',
#                                                    'Overall Cond', 'Year Built',
#                                                    'Year Remod/Add',
#                                                    'Total Bsmt SF',
#                                                    '2nd Flr SF', 'Gr Liv Area',
#                                                    'Bsmt Full Bath',
#                                                    'Full Bath', 'Half Bath',
#                                                    'Bedroom AbvGr',
#                                                    'TotRm...
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['MS Zoning', 'Lot Shape',
#                                                    'Land Contour', 'Lot Config',
#                                                    'Condition 1', 'Bldg Type',
#                                                    'House Style', 'Roof Style',
#                                                    'Exterior 1st',
#                                                    'Exterior 2nd', 'Exter Qual',
#                                                    'Exter Cond', 'Foundation',
#                                                    'Bsmt Cond', 'Heating QC',
#                                                    'Central Air',
#                                                    'Kitchen Qual',
#                                                    'Garage Type',
#                                                    'Garage Finish',
#                                                    'Garage Qual'])])),
#                 ('regressor', ElasticNet(alpha=0.07, l1_ratio=0.85))])

# %% [markdown]
# ### Используем модель, найденную классификацией

# %%
classification = 1
clf = classification_df["Best Estimator"][classification]
clf
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['MS SubClass',
#                                                    'Lot Frontage', 'Lot Area',
#                                                    'Overall Qual',
#                                                    'Overall Cond', 'Year Built',
#                                                    'Year Remod/Add',
#                                                    'Total Bsmt SF',
#                                                    '2nd Flr SF', 'Gr Liv Area',
#                                                    'Bsmt Full Bath',
#                                                    'Full Bath', 'Half Bath',
#                                                    'Bedroom AbvGr',
#                                                    'TotRm...
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['MS Zoning', 'Lot Shape',
#                                                    'Land Contour', 'Lot Config',
#                                                    'Condition 1', 'Bldg Type',
#                                                    'House Style', 'Roof Style',
#                                                    'Exterior 1st',
#                                                    'Exterior 2nd', 'Exter Qual',
#                                                    'Exter Cond', 'Foundation',
#                                                    'Bsmt Cond', 'Heating QC',
#                                                    'Central Air',
#                                                    'Kitchen Qual',
#                                                    'Garage Type',
#                                                    'Garage Finish',
#                                                    'Garage Qual'])])),
#                 ('classifier',
#                  <catboost.core.CatBoostClassifier object at 0x0000022C656C5160>)])

# %%
models[0]["Best Estimator"][1]
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['MS SubClass',
#                                                    'Lot Frontage', 'Lot Area',
#                                                    'Overall Qual',
#                                                    'Overall Cond', 'Year Built',
#                                                    'Year Remod/Add',
#                                                    'Total Bsmt SF',
#                                                    '2nd Flr SF', 'Gr Liv Area',
#                                                    'Bsmt Full Bath',
#                                                    'Full Bath', 'Half Bath',
#                                                    'Bedroom AbvGr',
#                                                    'TotRm...
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['MS Zoning', 'Lot Shape',
#                                                    'Land Contour', 'Lot Config',
#                                                    'Condition 1', 'Bldg Type',
#                                                    'House Style', 'Roof Style',
#                                                    'Exterior 1st',
#                                                    'Exterior 2nd', 'Exter Qual',
#                                                    'Exter Cond', 'Foundation',
#                                                    'Bsmt Cond', 'Heating QC',
#                                                    'Central Air',
#                                                    'Kitchen Qual',
#                                                    'Garage Type',
#                                                    'Garage Finish',
#                                                    'Garage Qual'])])),
#                 ('regressor', ElasticNet(alpha=0.15, l1_ratio=0.75))])

# %% [markdown]
# ### Гибридная модель

# %%
hybrid_results = []

for classification in range(3):
    
    clf = classification_df["Best Estimator"][classification]
    probs = clf.predict_proba(X_test)
    y_class = clf.predict(X_test)
    
    for way in ['Pipeline', 'Soft Voting']:
        
        for regression in range(1, 3):
            
            y_pred = np.zeros(len(X_test))
            
            if way == 'Pipeline':
                for i in range(len(X_test)):
                    x_row = X_test.iloc[[i]]
                    y_pred[i] = models[y_class[i].item()]["Best Estimator"][regression].predict(x_row)[0]
            else:
                for i in range(len(X_test)):
                    x_row = X_test.iloc[[i]]
                    pred0 = models[0]["Best Estimator"][regression].predict(x_row)[0]
                    pred1 = models[1]["Best Estimator"][regression].predict(x_row)[0]
                    pred2 = models[2]["Best Estimator"][regression].predict(x_row)[0]
                    pred3 = models[3]["Best Estimator"][regression].predict(x_row)[0]
                    y_pred[i] = probs[i, 0] * pred0 + probs[i, 1] * pred1 + probs[i, 2] * pred2 + probs[i, 3] * pred3
            
            test_r2, mae, rmse   = r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), root_mean_squared_error(y_test, y_pred)
            
            hybrid_results.append({
                "Type of hybridization" : way,
                "Classification": classification_df["Model"][classification],
                "Model": models[0]["Model"][regression],
                "Test R²": test_r2,
                "Test MAE": mae,
                "Test RMSE": rmse
            })

# %%
hybrid_results_df = pd.DataFrame(hybrid_results)
hybrid_results_df.sort_values(by=[f"Test RMSE"])
# Out:
#    Type of hybridization Classification         Model   Test R²   Test MAE  \
# 6            Soft Voting       CatBoost    ElasticNet  0.928056  14.026155
# 2            Soft Voting   RandomForest    ElasticNet  0.927301  14.126699
# 10           Soft Voting        XGBoost    ElasticNet  0.923959  14.561280
# 0               Pipeline   RandomForest    ElasticNet  0.919284  15.665157
# 7            Soft Voting       CatBoost  RandomForest  0.915145  15.369713
# 4               Pipeline       CatBoost    ElasticNet  0.914766  15.786430
# 8               Pipeline        XGBoost    ElasticNet  0.911529  16.256698
# 11           Soft Voting        XGBoost  RandomForest  0.911188  15.787296
# 3            Soft Voting   RandomForest  RandomForest  0.905213  16.113788
# 1               Pipeline   RandomForest  RandomForest  0.903512  17.010351
# 5               Pipeline       CatBoost  RandomForest  0.899363  17.181928
# 9               Pipeline        XGBoost  RandomForest  0.895199  17.543245
#
#     Test RMSE
# 6   20.295159
# 2   20.401443
# 10  20.865075
# 0   21.496869
# 7   22.041111
# 4   22.090316
# 8   22.505885
# 11  22.549293
# 3   23.295385
# 1   23.503479
# 5   24.003540
# 9   24.495046

# %% [markdown]
# ### Вывод результатов baseline

# %%
results_df = pd.DataFrame(results).sort_values(by=[f"Test RMSE"])
results_df[['Model','Test R²','Test MAE','Test RMSE']]
# Out:
#           Model   Test R²   Test MAE  Test RMSE
# 1    ElasticNet  0.914270  16.065511  22.154541
# 2  RandomForest  0.905332  16.317320  23.280833
# 0           KNN  0.861995  19.347841  28.108901

# %% [markdown]
# ### Прирост точности (в процентах)

# %% [markdown]
# Лучший 'Soft Voting' (CatBoost + ElasticNet) по сравнению с baseline

# %%
(0.928056 - 0.914270)/0.914270*100, (16.065511 - 14.026155)/14.026155*100, (22.154541 - 20.295159)/20.295159*100
# Out:
# (1.5078696665098894, 14.53966536089186, 9.161702059096932)

# %% [markdown]
# Лучший 'Pipeline' (CatBoost + RandomForest) по сравнению с baseline

# %%
(0.919284 - 0.914270)/0.914270*100, (16.065511 - 15.665157)/15.665157*100, (22.154541 - 21.496869)/21.496869*100
# Out:
# (0.5484156758944253, 2.5556973351751284, 3.0593850667276152)

# %%
import pandas as pd

df = pd.read_csv('AmesHousing.csv')

# %%
df.shape
# Out:
# (2930, 82)

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
df.SalePrice /= 1000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# Order            2930.0  1.465500e+03  8.459625e+02  1.000000e+00
# PID              2930.0  7.144645e+08  1.887308e+08  5.263011e+08
# MS SubClass      2930.0  5.738737e+01  4.263802e+01  2.000000e+01
# Lot Frontage     2440.0  6.922459e+01  2.336533e+01  2.100000e+01
# Lot Area         2930.0  1.014792e+04  7.880018e+03  1.300000e+03
# Overall Qual     2930.0  6.094881e+00  1.411026e+00  1.000000e+00
# Overall Cond     2930.0  5.563140e+00  1.111537e+00  1.000000e+00
# Year Built       2930.0  1.971356e+03  3.024536e+01  1.872000e+03
# Year Remod/Add   2930.0  1.984267e+03  2.086029e+01  1.950000e+03
# Mas Vnr Area     2907.0  1.018968e+02  1.791126e+02  0.000000e+00
# BsmtFin SF 1     2929.0  4.426296e+02  4.555908e+02  0.000000e+00
# BsmtFin SF 2     2929.0  4.972243e+01  1.691685e+02  0.000000e+00
# Bsmt Unf SF      2929.0  5.592625e+02  4.394942e+02  0.000000e+00
# ...

# %% [markdown]
# ### Исходя из информации выше, можно сразу удалить следующие столбцы: Pool QC, Fence, Misc Feature, Alley, Mas Vnr Type, Fireplace Qu, поскольку пропусков слишком много, а также: Order, PID, Mo Sold, Yr Sold, Pool Area, 3Ssn Porch поскольку они не несут информативности.

# %%
df['Street'].value_counts()
# Out:
# Street
# Pave    2918
# Grvl      12
# Name: count, dtype: int64

# %%
df['Utilities'].value_counts()
# Out:
# Utilities
# AllPub    2927
# NoSewr       2
# NoSeWa       1
# Name: count, dtype: int64

# %%
df['Land Slope'].value_counts()
# Out:
# Land Slope
# Gtl    2789
# Mod     125
# Sev      16
# Name: count, dtype: int64

# %%
df['Roof Matl'].value_counts()
# Out:
# Roof Matl
# CompShg    2887
# Tar&Grv      23
# WdShake       9
# WdShngl       7
# Membran       1
# ClyTile       1
# Roll          1
# Metal         1
# Name: count, dtype: int64

# %%
df['Heating'].value_counts()
# Out:
# Heating
# GasA     2885
# GasW       27
# Grav        9
# Wall        6
# OthW        2
# Floor       1
# Name: count, dtype: int64

# %%
df['Functional'].value_counts()
# Out:
# Functional
# Typ     2728
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Sal        2
# Name: count, dtype: int64

# %%
df['Paved Drive'].value_counts()
# Out:
# Paved Drive
# Y    2652
# N     216
# P      62
# Name: count, dtype: int64

# %%
df['Mas Vnr Area'].value_counts()
# Out:
# Mas Vnr Area
# 0.0       1748
# 120.0       15
# 176.0       13
# 200.0       13
# 216.0       12
#           ...
# 714.0        1
# 647.0        1
# 1290.0       1
# 495.0        1
# 443.0        1
# Name: count, Length: 445, dtype: int64

# %%
df['Electrical'].value_counts()
# Out:
# Electrical
# SBrkr    2682
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: count, dtype: int64

# %%
df['Bsmt Exposure'].value_counts()
# Out:
# Bsmt Exposure
# No    1906
# Av     418
# Gd     284
# Mn     239
# Name: count, dtype: int64

# %%
df['Sale Condition'].value_counts()
# Out:
# Sale Condition
# Normal     2413
# Partial     245
# Abnorml     190
# Family       46
# Alloca       24
# AdjLand      12
# Name: count, dtype: int64

# %%
df['Sale Type'].value_counts()
# Out:
# Sale Type
# WD       2536
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# VWD         1
# Name: count, dtype: int64

# %%
(df['Garage Cond'] == df['Garage Qual']).sum()
# Out:
# np.int64(2621)

# %%
(df['Condition 1'] == df['Condition 2']).sum()
# Out:
# np.int64(2535)

# %%
(df['Garage Yr Blt'] == df['Year Built']).sum()
# Out:
# np.int64(2227)

# %% [markdown]
# ### Предлагаю также удалить столбцы, описывающие площади зон подвала и их качество, а именно ['Bsmt Qual', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF']. Оставить только 'Bsmt Cond' и 'Total Bsmt SF'

# %%
df_clean_1 = df.drop(['Pool QC', 'Fence', 'Misc Feature', 'Alley', 'Mas Vnr Type', 'Mo Sold', 'Yr Sold', 'Pool Area', '3Ssn Porch', 'Sale Type',
                      'Fireplace Qu', 'Order', 'PID', 'Street', 'Utilities', 'Condition 2', 'Mas Vnr Area', 'Electrical', 'Garage Cond',
                      'Land Slope', 'Garage Yr Blt', 'Roof Matl', 'Heating', 'Functional', 'Paved Drive', 'Misc Val', 'Bsmt Qual', 'Neighborhood',
                      'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Sale Condition'], axis=1)

# %%
df_clean_1.describe().T
# Out:
#                   count          mean          std       min      25%     50%  \
# MS SubClass      2930.0     57.387372    42.638025    20.000    20.00    50.0
# Lot Frontage     2440.0     69.224590    23.365335    21.000    58.00    68.0
# Lot Area         2930.0  10147.921843  7880.017759  1300.000  7440.25  9436.5
# Overall Qual     2930.0      6.094881     1.411026     1.000     5.00     6.0
# Overall Cond     2930.0      5.563140     1.111537     1.000     5.00     5.0
# Year Built       2930.0   1971.356314    30.245361  1872.000  1954.00  1973.0
# Year Remod/Add   2930.0   1984.266553    20.860286  1950.000  1965.00  1993.0
# Total Bsmt SF    2929.0   1051.614544   440.615067     0.000   793.00   990.0
# 1st Flr SF       2930.0   1159.557679   391.890885   334.000   876.25  1084.0
# 2nd Flr SF       2930.0    335.455973   428.395715     0.000     0.00     0.0
# Low Qual Fin SF  2930.0      4.676792    46.310510     0.000     0.00     0.0
# ...

# %%
df_clean_1.isna().sum()
# Out:
# MS SubClass          0
# MS Zoning            0
# Lot Frontage       490
# Lot Area             0
# Lot Shape            0
# Land Contour         0
# Lot Config           0
# Condition 1          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Exterior 1st         0
# Exterior 2nd         0
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Cond           80
# Total Bsmt SF        1
# Heating QC           0
# Central Air          0
# 1st Flr SF           0
# 2nd Flr SF           0
# Low Qual Fin SF      0
# Gr Liv Area          0
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Full Bath            0
# Half Bath            0
# Bedroom AbvGr        0
# Kitchen AbvGr        0
# Kitchen Qual         0
# TotRms AbvGrd        0
# Fireplaces           0
# Garage Type        157
# Garage Finish      159
# Garage Cars          1
# ...

# %%
df_clean_1['Lot Frontage'].fillna(df['Lot Frontage'].mean(), inplace=True)
# Out:
# C:\Temp\ipykernel_2256\1922702563.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean_1['Lot Frontage'].fillna(df['Lot Frontage'].mean(), inplace=True)

# %% [markdown]
# TODO - проверить не изменилось ли распределение после замены пропущенных значений на среднее

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
num_df1_clean = df_clean_1.select_dtypes(include=['int64', 'float64'])

corr_matr = num_df1_clean.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matr, annot=False, cmap='winter')
plt.show()

# %% [markdown]
# ### Garage Cars и Garage Area сильно скоррелированы. Оставим Garage Area.
# ### Также с Total Bsmt и 1st Flr SF (оно и логично, площадь подвала почти всегда равна площади 1 этажа. Оставим 1st Flr SF

# %%
df_clean_1.drop(columns=['Garage Cars', '1st Flr SF'], axis=1, inplace=True)

# %%
df_clean_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 45 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2930 non-null   int64
#  1   MS Zoning        2930 non-null   object
#  2   Lot Frontage     2930 non-null   float64
#  3   Lot Area         2930 non-null   int64
#  4   Lot Shape        2930 non-null   object
#  5   Land Contour     2930 non-null   object
#  6   Lot Config       2930 non-null   object
#  7   Condition 1      2930 non-null   object
#  8   Bldg Type        2930 non-null   object
#  9   House Style      2930 non-null   object
#  10  Overall Qual     2930 non-null   int64
#  11  Overall Cond     2930 non-null   int64
#  12  Year Built       2930 non-null   int64
#  13  Year Remod/Add   2930 non-null   int64
#  14  Roof Style       2930 non-null   object
#  15  Exterior 1st     2930 non-null   object
#  16  Exterior 2nd     2930 non-null   object
# ...

# %%
df_clean_1.isna().sum().sort_values(ascending=False).head(10)
# Out:
# Garage Qual       159
# Garage Finish     159
# Garage Type       157
# Bsmt Cond          80
# Bsmt Full Bath      2
# Bsmt Half Bath      2
# Total Bsmt SF       1
# Garage Area         1
# MS SubClass         0
# Bedroom AbvGr       0
# dtype: int64

# %%
df_clean_1.shape
# Out:
# (2930, 45)

# %%
numeric_cols = df_clean_1.select_dtypes(include=['int64', 'float64'])

condition = pd.Series(True, index=df_clean_1.index)

for col in numeric_cols.columns:
    first_quartile = df_clean_1[col].describe()['25%']
    third_quartile = df_clean_1[col].describe()['75%']
    iqr = third_quartile - first_quartile

    condition &= (df_clean_1[col] >= (first_quartile - 3 * iqr)) & (df_clean_1[col] <= (third_quartile + 3 * iqr))

df_clean2 = df_clean_1[condition]

# %%
df_clean2.shape
# Out:
# (1905, 45)

# %%
df_clean2['SalePrice'].describe().T
# Out:
# count    1905.000000
# mean      186.373984
# std        73.340983
# min        12.789000
# 25%       134.000000
# 50%       173.000000
# 75%       222.000000
# max       465.000000
# Name: SalePrice, dtype: float64

# %%
df_clean2.hist(figsize=(20, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %% [markdown]
# Из построенных графиков выше можно заключить, что следующие признаки распределены нормально:
# ['Garage Area', 'TotRms AbvGrd', 'Gr Liv Area', 'Total Bsmt SF', 'Overall Cond', 'Overall Qual', 'Lot Frontage', 'Lot Area', 'SalePrice']
#
# Распределены иначе:
# ['Ms SubClass', 'Year Built', 'Year Remond/Add', '2nd Flr SF', 'Bsmt Full Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Fireplaces', 'Wood Desk SF', 'Open Porch SF']
#
# Следует удалить из выборки, поскольку принимает одно единственное значение, которое на результат не оказывает влияние:
# ['Low Qual Fin SF', 'Bsmt Half Bath', 'Kitchen AbvGr', 'Enclosed Porch', 'Screen Porch']

# %%
df_clean2 = df_clean2.drop(['Low Qual Fin SF', 'Bsmt Half Bath', 'Kitchen AbvGr', 'Enclosed Porch', 'Screen Porch'], axis=1)

# %%
df_clean2.shape
# Out:
# (1905, 40)

# %%
df = df_clean2

# %%
df[df['Gr Liv Area'] > 4000]
# Out:
# Empty DataFrame
# Columns: [MS SubClass, MS Zoning, Lot Frontage, Lot Area, Lot Shape, Land Contour, Lot Config, Condition 1, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Exterior 1st, Exterior 2nd, Exter Qual, Exter Cond, Foundation, Bsmt Cond, Total Bsmt SF, Heating QC, Central Air, 2nd Flr SF, Gr Liv Area, Bsmt Full Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen Qual, TotRms AbvGrd, Fireplaces, Garage Type, Garage Finish, Garage Area, Garage Qual, Wood Deck SF, Open Porch SF, SalePrice]
# Index: []
#
# [0 rows x 40 columns]

# %%
df.to_csv('clean.csv', index=False)

# %% [markdown]
# ## прогнали линейную регрессию с L1 регуляризацией для выяснения наличия линейной зависимости признаков

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Целевая переменная и признаки
y = df["SalePrice"]
X = df.drop(columns=["SalePrice"])

# Разделяем типы признаков
numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = X.select_dtypes(include=["object"]).columns.tolist()

# Препроцессоры
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", RobustScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="constant", fill_value="Missing")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer([
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features)
])

# Lasso регрессия
model = Lasso(max_iter=10000)

# Pipeline
pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("regressor", model)
])

# Сетка параметров для подбора alpha
params = {
    "regressor__alpha": [0.001, 0.01, 0.1, 1, 10]
}

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# GridSearchCV
grid = GridSearchCV(pipe, param_grid=params, scoring="r2", cv=3, n_jobs=-1)
grid.fit(X_train, y_train)

# Предсказание
y_pred = grid.predict(X_test)

# Метрики
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)

print(f"Best alpha: {grid.best_params_}")
print(f"Test R²: {r2:.4f}, MAE: {mae:.2f}, RMSE: {rmse:.2f}")

# === Извлекаем коэффициенты модели ===
best_model = grid.best_estimator_.named_steps["regressor"]

# Получаем имена признаков после OneHotEncoding
feature_names = grid.best_estimator_.named_steps["preprocessing"].get_feature_names_out()
coefficients = best_model.coef_

coef_df = pd.DataFrame({
    "feature": feature_names,
    "coefficient": coefficients
}).sort_values(by="coefficient", key=np.abs, ascending=False)

# Смотрим, какие коэффициенты обнулились
zero_coefs = coef_df[coef_df["coefficient"] == 0]
nonzero_coefs = coef_df[coef_df["coefficient"] != 0]

print(f"Нулевых коэффициентов: {len(zero_coefs)} из {len(coef_df)}")
print(coef_df.head(10))
print('------------')
print(zero_coefs)
# Out:
# Best alpha: {'regressor__alpha': 10}
# Test R²: 0.7981, MAE: 16393.90, RMSE: 1325370781.61
# Нулевых коэффициентов: 93 из 317
#                        feature    coefficient
# 132     cat__Roof Matl_ClyTile -647377.854664
# 79   cat__Neighborhood_GrnHill  109018.720128
# 286            cat__Pool QC_Ex   79527.844669
# 108      cat__Condition 2_PosA   50693.776928
# 271        cat__Garage Qual_Ex   47748.340452
# 138     cat__Roof Matl_WdShngl   40572.874474
# 93   cat__Neighborhood_StoneBr   38360.216067
# 173   cat__Mas Vnr Type_CBlock  -37278.082658
# 86   cat__Neighborhood_NoRidge   35437.163400
# 17            num__Gr Liv Area   32313.689752
# ------------
#                          feature  coefficient
# 297    cat__Misc Feature_Missing         -0.0
# 315   cat__Sale Condition_Normal          0.0
# 296       cat__Misc Feature_Gar2         -0.0
# 306         cat__Sale Type_ConLw          0.0
# 289         cat__Pool QC_Missing         -0.0
# ...

# %% [markdown]
# TODO - выделить название колонок, которые являются линейно зависимыми

# %%
features = zero_coefs.feature.to_list()
zero_features = set()
for feature in features:
    cutter = feature.replace('cat__', '').replace('num__', '')
    cutter = cutter[: cutter.find('_')]
    zero_features.add(cutter)
print('zero_features length', len(zero_features))
zero_features
# Out:
# zero_features length 40
# {'1st Flr S',
#  'Alley',
#  'Bldg Type',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'Bsmt Qual',
#  'Bsmt Unf S',
#  'BsmtFin Type 1',
#  'BsmtFin Type 2',
#  'Condition 1',
#  'Condition 2',
#  'Electrical',
#  'Exter Cond',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Fence',
#  'Functional',
#  'Garage Cond',
#  'Garage Finish',
#  'Garage Qual',
#  'Garage Type',
#  'Heating',
#  'Heating QC',
#  'Kitchen Qual',
#  'Land Slope',
#  'Lot Config',
#  'Lot Shape',
#  'MS Zoning',
#  'Mas Vnr Type',
#  'Misc Feature',
#  'Neighborhood',
#  'Orde',
#  'Paved Drive',
#  'Pool QC',
#  'Roof Matl',
#  'Roof Style',
#  'Sale Condition',
#  'Sale Type',
#  'Street',
#  'Utilities'}

# %% [markdown]
# TODO - выкинуть линейно зависимые колонки
